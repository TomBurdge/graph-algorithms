# %% [markdown]
# # 6 Shortest Path

# %% [markdown]
# <p>We are going to get a graph with a list of edges.</p>We'll want to convert it into an adjacency list.<br><br>Then, we'll end up with a graph that looks like this:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We'll be given two nodes: W and z.<br>We want to find the shortest distance (in this case, fewest edges) between them.<br>
# The shortest path here would be the route that uses only two edges: ![image.png](attachment:image.png)<br>Return 2.

# %% [markdown]
# What would be better here, breadth or depth first?<br>Answer: breadth first is best. Looks at all the shortest routes in increments.<br>![image.png](attachment:image.png)

# %% [markdown]
# ## Pseudo-code solution

# %% [markdown]
# start at w, go to x.<br>For each movement, will want to the letter and a number which marks the distance.<br>Start at (x,0), then to (w,1).<br>The neighbours are in the queue.<br>Need to make sure we don't end up in an infinite loop where we keep going back to w.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)<br>![image-2.png](attachment:image-2.png)<br>![image-3.png](attachment:image-3.png)

# %% [markdown]
# Linear complexity again

# %% [markdown]
# ## Code solution

# %% [markdown]
# I've already done the building the graph in 3-undirected-path. So, I'm going to import that function from a python file.

# %%
from build_graph.py import *

# %%
def edges_to_adjaceny_list(edges):
    graph ={}
    for edge in edges
    return graph

def shortest_path(graph, start_node, finish_node):
